# %% [markdown]
# ## Day 20 作業：將 missing 值替代為其他值
#
# 由於現實世界中的資料可能有缺漏，因此資料中就會有 missing 值存在，而在資料科學及機器學習中，缺漏值的處理關係到分析或預測的結果。
#
# 在今天的作業中，請將資料集中的年齡缺漏值，依性別分別替換為資料集中男性或女性的年齡平均值。
#
# 本次作業使用的資料集：Kaggle Titanic: Machine Learning from Disaster 的 train 資料集
#
# 競賽主頁：[https://www.kaggle.com/c/titanic/overview](https://www.kaggle.com/c/titanic/overview)
#
# 請自行下載資料集 **train.csv**：[https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)

# %%
using DataFrames, CSV

# %%
df = CSV.read("train.csv")
# Out:
# 891×12 DataFrame. Omitted printing of 9 columns
# │ Row │ PassengerId │ Survived │ Pclass │
# │     │ Int64       │ Int64    │ Int64  │
# ├─────┼─────────────┼──────────┼────────┤
# │ 1   │ 1           │ 0        │ 3      │
# │ 2   │ 2           │ 1        │ 1      │
# │ 3   │ 3           │ 1        │ 3      │
# │ 4   │ 4           │ 1        │ 1      │
# │ 5   │ 5           │ 0        │ 3      │
# │ 6   │ 6           │ 0        │ 3      │
# │ 7   │ 7           │ 0        │ 1      │
# │ 8   │ 8           │ 0        │ 3      │
# │ 9   │ 9           │ 1        │ 3      │
# │ 10  │ 10          │ 1        │ 2      │
# ⋮
# │ 881 │ 881         │ 1        │ 2      │
# │ 882 │ 882         │ 0        │ 3      │
# │ 883 │ 883         │ 0        │ 3      │
# │ 884 │ 884         │ 0        │ 2      │
# │ 885 │ 885         │ 0        │ 3      │
# │ 886 │ 886         │ 0        │ 3      │
# │ 887 │ 887         │ 0        │ 2      │
# │ 888 │ 888         │ 1        │ 1      │
# │ 889 │ 889         │ 0        │ 3      │
# │ 890 │ 890         │ 1        │ 1      │
# │ 891 │ 891         │ 0        │ 3      │

# %%
size(df)
# Out:
# (891, 12)

# %% [markdown]
# 呼叫 `describe()` 函式時，加上 `:nmissing` 參數，顯示各 column 的 missing 值數目。
#
# 可以看到 Age 共有 177 個缺漏值。

# %%
describe(df, :nmissing)
# Out:
# 12×2 DataFrame
# │ Row │ variable    │ nmissing │
# │     │ Symbol      │ Union…   │
# ├─────┼─────────────┼──────────┤
# │ 1   │ PassengerId │          │
# │ 2   │ Survived    │          │
# │ 3   │ Pclass      │          │
# │ 4   │ Name        │          │
# │ 5   │ Sex         │          │
# │ 6   │ Age         │ 177      │
# │ 7   │ SibSp       │          │
# │ 8   │ Parch       │          │
# │ 9   │ Ticket      │          │
# │ 10  │ Fare        │          │
# │ 11  │ Cabin       │ 687      │
# │ 12  │ Embarked    │ 2        │

# %% [markdown]
# 計算男性及女性的平均年齡。
#
# 【提示】使用 `skipmissing()` 去掉缺漏值後，再計算平均值。

# %%
using Statistics

# %%
male_df = df[df[:, :Sex] .== "male", :]
nomissing_male_age = collect(skipmissing(male_df[:, :Age]))
male_age_avg = mean(nomissing_male_age)
# Out:
# 30.72664459161148

# %%
female_df = df[df[:, :Sex] .== "female", :]
nomissing_female_age = collect(skipmissing(female_df[:, :Age]))
female_age_avg = mean(nomissing_female_age)
# Out:
# 27.915708812260537

# %% [markdown]
# 將 Age column 中的 missing 值，依性別替換為上面計算出來的平均年齡值。
#
# 【提示】可產生新的 column 來存放新的結果，而不取代掉原先的 Age column。

# %%
# 請輸入程式碼
male_age_df = coalesce.(male_df, male_age_avg)
female_age_df = coalesce.(female_df, female_age_avg)
new_df = vcat(male_age_df, female_age_df)
# Out:
# 891×12 DataFrame. Omitted printing of 9 columns
# │ Row │ PassengerId │ Survived │ Pclass │
# │     │ Int64       │ Int64    │ Int64  │
# ├─────┼─────────────┼──────────┼────────┤
# │ 1   │ 1           │ 0        │ 3      │
# │ 2   │ 5           │ 0        │ 3      │
# │ 3   │ 6           │ 0        │ 3      │
# │ 4   │ 7           │ 0        │ 1      │
# │ 5   │ 8           │ 0        │ 3      │
# │ 6   │ 13          │ 0        │ 3      │
# │ 7   │ 14          │ 0        │ 3      │
# │ 8   │ 17          │ 0        │ 3      │
# │ 9   │ 18          │ 1        │ 2      │
# │ 10  │ 21          │ 0        │ 2      │
# ⋮
# │ 881 │ 866         │ 1        │ 2      │
# │ 882 │ 867         │ 1        │ 2      │
# │ 883 │ 872         │ 1        │ 1      │
# │ 884 │ 875         │ 1        │ 2      │
# │ 885 │ 876         │ 1        │ 3      │
# │ 886 │ 880         │ 1        │ 1      │
# │ 887 │ 881         │ 1        │ 2      │
# │ 888 │ 883         │ 0        │ 3      │
# │ 889 │ 886         │ 0        │ 3      │
# │ 890 │ 888         │ 1        │ 1      │
# │ 891 │ 889         │ 0        │ 3      │

# %%
show(new_df[:, [:Sex, :Age]], allrows=true)
# Out:
# 891×2 DataFrame
# │ Row │ Sex    │ Age     │
# │     │ String │ Float64 │
# ├─────┼────────┼─────────┤
# │ 1   │ male   │ 22.0    │
# │ 2   │ male   │ 35.0    │
# │ 3   │ male   │ 30.7266 │
# │ 4   │ male   │ 54.0    │
# │ 5   │ male   │ 2.0     │
# │ 6   │ male   │ 20.0    │
# │ 7   │ male   │ 39.0    │
# │ 8   │ male   │ 2.0     │
# │ 9   │ male   │ 30.7266 │
# │ 10  │ male   │ 35.0    │
# │ 11  │ male   │ 34.0    │
# │ 12  │ male   │ 28.0    │
# │ 13  │ male   │ 30.7266 │
# │ 14  │ male   │ 19.0    │
# │ 15  │ male   │ 30.7266 │
# │ 16  │ male   │ 40.0    │
# │ 17  │ male   │ 66.0    │
# │ 18  │ male   │ 28.0    │
# │ 19  │ male   │ 42.0    │
# │ 20  │ male   │ 30.7266 │
# │ 21  │ male   │ 21.0    │
# │ 22  │ male   │ 30.7266 │
# │ 23  │ male   │ 30.7266 │
# │ 24  │ male   │ 30.7266 │
# │ 25  │ male   │ 30.7266 │
# │ 26  │ male   │ 7.0     │
# │ 27  │ male   │ 21.0    │
# │ 28  │ male   │ 65.0    │
# │ 29  │ male   │ 30.7266 │
# │ 30  │ male   │ 28.5    │
# │ 31  │ male   │ 11.0    │
# │ 32  │ male   │ 22.0    │
# │ 33  │ male   │ 45.0    │
# │ 34  │ male   │ 4.0     │
# │ 35  │ male   │ 30.7266 │
# │ 36  │ male   │ 30.7266 │
# │ 37  │ male   │ 19.0    │
# │ 38  │ male   │ 26.0    │
# │ 39  │ male   │ 32.0    │
# │ 40  │ male   │ 21.0    │
# │ 41  │ male   │ 26.0    │
# │ 42  │ male   │ 32.0    │
# │ 43  │ male   │ 25.0    │
# │ 44  │ male   │ 30.7266 │
# │ 45  │ male   │ 30.7266 │
# │ 46  │ male   │ 0.83    │
# │ 47  │ male   │ 22.0    │
# │ 48  │ male   │ 29.0    │
# │ 49  │ male   │ 28.0    │
# │ 50  │ male   │ 16.0    │
# │ 51  │ male   │ 30.7266 │
# │ 52  │ male   │ 24.0    │
# │ 53  │ male   │ 29.0    │
# │ 54  │ male   │ 20.0    │
# │ 55  │ male   │ 46.0    │
# │ 56  │ male   │ 26.0    │
# │ 57  │ male   │ 59.0    │
# │ 58  │ male   │ 30.7266 │
# │ 59  │ male   │ 71.0    │
# │ 60  │ male   │ 23.0    │
# │ 61  │ male   │ 34.0    │
# │ 62  │ male   │ 30.7266 │
# │ 63  │ male   │ 21.0    │
# │ 64  │ male   │ 33.0    │
# │ 65  │ male   │ 37.0    │
# │ 66  │ male   │ 28.0    │
# │ 67  │ male   │ 30.7266 │
# │ 68  │ male   │ 38.0    │
# │ 69  │ male   │ 47.0    │
# │ 70  │ male   │ 22.0    │
# │ 71  │ male   │ 21.0    │
# │ 72  │ male   │ 70.5    │
# │ 73  │ male   │ 29.0    │
# │ 74  │ male   │ 24.0    │
# │ 75  │ male   │ 21.0    │
# │ 76  │ male   │ 30.7266 │
# │ 77  │ male   │ 32.5    │
# │ 78  │ male   │ 54.0    │
# │ 79  │ male   │ 12.0    │
# │ 80  │ male   │ 30.7266 │
# │ 81  │ male   │ 24.0    │
# │ 82  │ male   │ 45.0    │
# │ 83  │ male   │ 33.0    │
# │ 84  │ male   │ 20.0    │
# │ 85  │ male   │ 25.0    │
# │ 86  │ male   │ 23.0    │
# │ 87  │ male   │ 37.0    │
# │ 88  │ male   │ 16.0    │
# │ 89  │ male   │ 24.0    │
# │ 90  │ male   │ 19.0    │
# │ 91  │ male   │ 18.0    │
# │ 92  │ male   │ 19.0    │
# │ 93  │ male   │ 27.0    │
# │ 94  │ male   │ 36.5    │
# │ 95  │ male   │ 42.0    │
# │ 96  │ male   │ 51.0    │
# │ 97  │ male   │ 55.5    │
# │ 98  │ male   │ 40.5    │
# │ 99  │ male   │ 30.7266 │
# │ 100 │ male   │ 51.0    │
# │ 101 │ male   │ 30.0    │
# │ 102 │ male   │ 30.7266 │
# │ 103 │ male   │ 30.7266 │
# │ 104 │ male   │ 44.0    │
# │ 105 │ male   │ 26.0    │
# │ 106 │ male   │ 17.0    │
# │ 107 │ male   │ 1.0     │
# │ 108 │ male   │ 9.0     │
# │ 109 │ male   │ 30.7266 │
# │ 110 │ male   │ 28.0    │
# │ 111 │ male   │ 61.0    │
# │ 112 │ male   │ 4.0     │
# │ 113 │ male   │ 21.0    │
# │ 114 │ male   │ 56.0    │
# │ 115 │ male   │ 18.0    │
# │ 116 │ male   │ 30.7266 │
# │ 117 │ male   │ 30.0    │
# │ 118 │ male   │ 36.0    │
# │ 119 │ male   │ 30.7266 │
# │ 120 │ male   │ 9.0     │
# │ 121 │ male   │ 1.0     │
# │ 122 │ male   │ 30.7266 │
# │ 123 │ male   │ 45.0    │
# │ 124 │ male   │ 40.0    │
# │ 125 │ male   │ 36.0    │
# │ 126 │ male   │ 19.0    │
# │ 127 │ male   │ 3.0     │
# │ 128 │ male   │ 30.7266 │
# │ 129 │ male   │ 42.0    │
# │ 130 │ male   │ 28.0    │
# │ 131 │ male   │ 30.7266 │
# │ 132 │ male   │ 34.0    │
# │ 133 │ male   │ 45.5    │
# │ 134 │ male   │ 18.0    │
# │ 135 │ male   │ 32.0    │
# │ 136 │ male   │ 26.0    │
# │ 137 │ male   │ 40.0    │
# │ 138 │ male   │ 24.0    │
# │ 139 │ male   │ 22.0    │
# │ 140 │ male   │ 30.0    │
# │ 141 │ male   │ 30.7266 │
# │ 142 │ male   │ 42.0    │
# │ 143 │ male   │ 30.0    │
# │ 144 │ male   │ 16.0    │
# │ 145 │ male   │ 27.0    │
# │ 146 │ male   │ 51.0    │
# │ 147 │ male   │ 30.7266 │
# │ 148 │ male   │ 38.0    │
# │ 149 │ male   │ 22.0    │
# │ 150 │ male   │ 19.0    │
# │ 151 │ male   │ 20.5    │
# │ 152 │ male   │ 18.0    │
# │ 153 │ male   │ 29.0    │
# │ 154 │ male   │ 59.0    │
# │ 155 │ male   │ 24.0    │
# │ 156 │ male   │ 44.0    │
# │ 157 │ male   │ 19.0    │
# │ 158 │ male   │ 33.0    │
# │ 159 │ male   │ 29.0    │
# │ 160 │ male   │ 22.0    │
# │ 161 │ male   │ 30.0    │
# │ 162 │ male   │ 44.0    │
# │ 163 │ male   │ 37.0    │
# │ 164 │ male   │ 54.0    │
# │ 165 │ male   │ 30.7266 │
# │ 166 │ male   │ 62.0    │
# │ 167 │ male   │ 30.0    │
# │ 168 │ male   │ 30.7266 │
# │ 169 │ male   │ 3.0     │
# │ 170 │ male   │ 52.0    │
# │ 171 │ male   │ 40.0    │
# │ 172 │ male   │ 36.0    │
# │ 173 │ male   │ 16.0    │
# │ 174 │ male   │ 25.0    │
# │ 175 │ male   │ 30.7266 │
# │ 176 │ male   │ 25.0    │
# │ 177 │ male   │ 37.0    │
# │ 178 │ male   │ 30.7266 │
# │ 179 │ male   │ 7.0     │
# │ 180 │ male   │ 65.0    │
# │ 181 │ male   │ 28.0    │
# │ 182 │ male   │ 16.0    │
# │ 183 │ male   │ 19.0    │
# │ 184 │ male   │ 30.7266 │
# │ 185 │ male   │ 33.0    │
# │ 186 │ male   │ 30.0    │
# │ 187 │ male   │ 22.0    │
# │ 188 │ male   │ 42.0    │
# │ 189 │ male   │ 36.0    │
# │ 190 │ male   │ 24.0    │
# │ 191 │ male   │ 30.7266 │
# │ 192 │ male   │ 23.5    │
# │ 193 │ male   │ 30.7266 │
# │ 194 │ male   │ 30.7266 │
# │ 195 │ male   │ 19.0    │
# │ 196 │ male   │ 30.7266 │
# │ 197 │ male   │ 0.92    │
# │ 198 │ male   │ 30.0    │
# │ 199 │ male   │ 28.0    │
# │ 200 │ male   │ 43.0    │
# │ 201 │ male   │ 54.0    │
# │ 202 │ male   │ 22.0    │
# │ 203 │ male   │ 27.0    │
# │ 204 │ male   │ 30.7266 │
# │ 205 │ male   │ 61.0    │
# │ 206 │ male   │ 45.5    │
# │ 207 │ male   │ 38.0    │
# │ 208 │ male   │ 16.0    │
# │ 209 │ male   │ 30.7266 │
# │ 210 │ male   │ 29.0    │
# │ 211 │ male   │ 45.0    │
# │ 212 │ male   │ 45.0    │
# │ 213 │ male   │ 2.0     │
# │ 214 │ male   │ 28.0    │
# │ 215 │ male   │ 25.0    │
# │ 216 │ male   │ 36.0    │
# │ 217 │ male   │ 3.0     │
# │ 218 │ male   │ 42.0    │
# │ 219 │ male   │ 23.0    │
# │ 220 │ male   │ 30.7266 │
# │ 221 │ male   │ 15.0    │
# │ 222 │ male   │ 25.0    │
# │ 223 │ male   │ 30.7266 │
# │ 224 │ male   │ 28.0    │
# │ 225 │ male   │ 40.0    │
# │ 226 │ male   │ 29.0    │
# │ 227 │ male   │ 35.0    │
# │ 228 │ male   │ 30.7266 │
# │ 229 │ male   │ 30.0    │
# │ 230 │ male   │ 25.0    │
# │ 231 │ male   │ 18.0    │
# │ 232 │ male   │ 19.0    │
# │ 233 │ male   │ 22.0    │
# │ 234 │ male   │ 27.0    │
# │ 235 │ male   │ 20.0    │
# │ 236 │ male   │ 19.0    │
# │ 237 │ male   │ 32.0    │
# │ 238 │ male   │ 30.7266 │
# │ 239 │ male   │ 18.0    │
# │ 240 │ male   │ 1.0     │
# │ 241 │ male   │ 30.7266 │
# │ 242 │ male   │ 36.0    │
# │ 243 │ male   │ 21.0    │
# │ 244 │ male   │ 28.0    │
# │ 245 │ male   │ 22.0    │
# │ 246 │ male   │ 46.0    │
# │ 247 │ male   │ 23.0    │
# │ 248 │ male   │ 39.0    │
# │ 249 │ male   │ 26.0    │
# │ 250 │ male   │ 28.0    │
# │ 251 │ male   │ 34.0    │
# │ 252 │ male   │ 51.0    │
# │ 253 │ male   │ 3.0     │
# │ 254 │ male   │ 21.0    │
# │ 255 │ male   │ 30.7266 │
# │ 256 │ male   │ 30.7266 │
# │ 257 │ male   │ 30.7266 │
# │ 258 │ male   │ 44.0    │
# │ 259 │ male   │ 30.0    │
# │ 260 │ male   │ 30.7266 │
# │ 261 │ male   │ 21.0    │
# │ 262 │ male   │ 29.0    │
# │ 263 │ male   │ 18.0    │
# │ 264 │ male   │ 30.7266 │
# │ 265 │ male   │ 30.7266 │
# │ 266 │ male   │ 32.0    │
# │ 267 │ male   │ 28.0    │
# │ 268 │ male   │ 17.0    │
# │ 269 │ male   │ 50.0    │
# │ 270 │ male   │ 64.0    │
# │ 271 │ male   │ 31.0    │
# │ 272 │ male   │ 20.0    │
# │ 273 │ male   │ 25.0    │
# │ 274 │ male   │ 30.7266 │
# │ 275 │ male   │ 4.0     │
# │ 276 │ male   │ 34.0    │
# │ 277 │ male   │ 52.0    │
# │ 278 │ male   │ 36.0    │
# │ 279 │ male   │ 30.7266 │
# │ 280 │ male   │ 30.0    │
# │ 281 │ male   │ 49.0    │
# │ 282 │ male   │ 30.7266 │
# │ 283 │ male   │ 29.0    │
# │ 284 │ male   │ 65.0    │
# │ 285 │ male   │ 30.7266 │
# │ 286 │ male   │ 48.0    │
# │ 287 │ male   │ 34.0    │
# │ 288 │ male   │ 47.0    │
# │ 289 │ male   │ 48.0    │
# │ 290 │ male   │ 30.7266 │
# │ 291 │ male   │ 38.0    │
# │ 292 │ male   │ 30.7266 │
# │ 293 │ male   │ 56.0    │
# │ 294 │ male   │ 30.7266 │
# │ 295 │ male   │ 30.7266 │
# │ 296 │ male   │ 38.0    │
# │ 297 │ male   │ 30.7266 │
# │ 298 │ male   │ 34.0    │
# │ 299 │ male   │ 29.0    │
# │ 300 │ male   │ 22.0    │
# │ 301 │ male   │ 9.0     │
# │ 302 │ male   │ 30.7266 │
# │ 303 │ male   │ 50.0    │
# │ 304 │ male   │ 25.0    │
# │ 305 │ male   │ 58.0    │
# │ 306 │ male   │ 30.0    │
# │ 307 │ male   │ 9.0     │
# │ 308 │ male   │ 30.7266 │
# │ 309 │ male   │ 21.0    │
# │ 310 │ male   │ 55.0    │
# │ 311 │ male   │ 71.0    │
# │ 312 │ male   │ 21.0    │
# │ 313 │ male   │ 30.7266 │
# │ 314 │ male   │ 30.7266 │
# │ 315 │ male   │ 24.0    │
# │ 316 │ male   │ 17.0    │
# │ 317 │ male   │ 18.0    │
# │ 318 │ male   │ 30.7266 │
# │ 319 │ male   │ 28.0    │
# │ 320 │ male   │ 26.0    │
# │ 321 │ male   │ 29.0    │
# │ 322 │ male   │ 30.7266 │
# │ 323 │ male   │ 36.0    │
# │ 324 │ male   │ 24.0    │
# │ 325 │ male   │ 47.0    │
# │ 326 │ male   │ 30.7266 │
# │ 327 │ male   │ 32.0    │
# │ 328 │ male   │ 22.0    │
# │ 329 │ male   │ 30.7266 │
# │ 330 │ male   │ 30.7266 │
# │ 331 │ male   │ 40.5    │
# │ 332 │ male   │ 30.7266 │
# │ 333 │ male   │ 39.0    │
# │ 334 │ male   │ 23.0    │
# │ 335 │ male   │ 30.7266 │
# │ 336 │ male   │ 17.0    │
# │ 337 │ male   │ 45.0    │
# │ 338 │ male   │ 30.7266 │
# │ 339 │ male   │ 32.0    │
# │ 340 │ male   │ 50.0    │
# │ 341 │ male   │ 64.0    │
# │ 342 │ male   │ 30.7266 │
# │ 343 │ male   │ 33.0    │
# │ 344 │ male   │ 8.0     │
# │ 345 │ male   │ 17.0    │
# │ 346 │ male   │ 27.0    │
# │ 347 │ male   │ 30.7266 │
# │ 348 │ male   │ 22.0    │
# │ 349 │ male   │ 62.0    │
# │ 350 │ male   │ 30.7266 │
# │ 351 │ male   │ 30.7266 │
# │ 352 │ male   │ 40.0    │
# │ 353 │ male   │ 28.0    │
# │ 354 │ male   │ 30.7266 │
# │ 355 │ male   │ 24.0    │
# │ 356 │ male   │ 19.0    │
# │ 357 │ male   │ 30.7266 │
# │ 358 │ male   │ 32.0    │
# │ 359 │ male   │ 62.0    │
# │ 360 │ male   │ 36.0    │
# │ 361 │ male   │ 16.0    │
# │ 362 │ male   │ 19.0    │
# │ 363 │ male   │ 32.0    │
# │ 364 │ male   │ 54.0    │
# │ 365 │ male   │ 36.0    │
# │ 366 │ male   │ 30.7266 │
# │ 367 │ male   │ 47.0    │
# │ 368 │ male   │ 60.0    │
# │ 369 │ male   │ 22.0    │
# │ 370 │ male   │ 30.7266 │
# │ 371 │ male   │ 35.0    │
# │ 372 │ male   │ 47.0    │
# │ 373 │ male   │ 37.0    │
# │ 374 │ male   │ 36.0    │
# │ 375 │ male   │ 49.0    │
# │ 376 │ male   │ 30.7266 │
# │ 377 │ male   │ 49.0    │
# │ 378 │ male   │ 30.7266 │
# │ 379 │ male   │ 30.7266 │
# │ 380 │ male   │ 44.0    │
# │ 381 │ male   │ 35.0    │
# │ 382 │ male   │ 36.0    │
# │ 383 │ male   │ 30.0    │
# │ 384 │ male   │ 27.0    │
# │ 385 │ male   │ 30.7266 │
# │ 386 │ male   │ 30.7266 │
# │ 387 │ male   │ 35.0    │
# │ 388 │ male   │ 34.0    │
# │ 389 │ male   │ 26.0    │
# │ 390 │ male   │ 27.0    │
# │ 391 │ male   │ 42.0    │
# │ 392 │ male   │ 20.0    │
# │ 393 │ male   │ 21.0    │
# │ 394 │ male   │ 21.0    │
# │ 395 │ male   │ 61.0    │
# │ 396 │ male   │ 57.0    │
# │ 397 │ male   │ 26.0    │
# │ 398 │ male   │ 30.7266 │
# │ 399 │ male   │ 80.0    │
# │ 400 │ male   │ 51.0    │
# │ 401 │ male   │ 32.0    │
# │ 402 │ male   │ 30.7266 │
# │ 403 │ male   │ 32.0    │
# │ 404 │ male   │ 31.0    │
# │ 405 │ male   │ 30.7266 │
# │ 406 │ male   │ 20.0    │
# │ 407 │ male   │ 30.7266 │
# │ 408 │ male   │ 48.0    │
# │ 409 │ male   │ 19.0    │
# │ 410 │ male   │ 56.0    │
# │ 411 │ male   │ 30.7266 │
# │ 412 │ male   │ 30.7266 │
# │ 413 │ male   │ 21.0    │
# │ 414 │ male   │ 24.0    │
# │ 415 │ male   │ 30.7266 │
# │ 416 │ male   │ 23.0    │
# │ 417 │ male   │ 58.0    │
# │ 418 │ male   │ 50.0    │
# │ 419 │ male   │ 40.0    │
# │ 420 │ male   │ 47.0    │
# │ 421 │ male   │ 36.0    │
# │ 422 │ male   │ 20.0    │
# │ 423 │ male   │ 32.0    │
# │ 424 │ male   │ 25.0    │
# │ 425 │ male   │ 30.7266 │
# │ 426 │ male   │ 43.0    │
# │ 427 │ male   │ 31.0    │
# │ 428 │ male   │ 70.0    │
# │ 429 │ male   │ 31.0    │
# │ 430 │ male   │ 30.7266 │
# │ 431 │ male   │ 18.0    │
# │ 432 │ male   │ 24.5    │
# │ 433 │ male   │ 36.0    │
# │ 434 │ male   │ 27.0    │
# │ 435 │ male   │ 20.0    │
# │ 436 │ male   │ 14.0    │
# │ 437 │ male   │ 60.0    │
# │ 438 │ male   │ 25.0    │
# │ 439 │ male   │ 14.0    │
# │ 440 │ male   │ 19.0    │
# │ 441 │ male   │ 18.0    │
# │ 442 │ male   │ 31.0    │
# │ 443 │ male   │ 30.7266 │
# │ 444 │ male   │ 25.0    │
# │ 445 │ male   │ 60.0    │
# │ 446 │ male   │ 52.0    │
# │ 447 │ male   │ 44.0    │
# │ 448 │ male   │ 49.0    │
# │ 449 │ male   │ 42.0    │
# │ 450 │ male   │ 35.0    │
# │ 451 │ male   │ 25.0    │
# │ 452 │ male   │ 26.0    │
# │ 453 │ male   │ 39.0    │
# │ 454 │ male   │ 42.0    │
# │ 455 │ male   │ 30.7266 │
# │ 456 │ male   │ 30.7266 │
# │ 457 │ male   │ 48.0    │
# │ 458 │ male   │ 29.0    │
# │ 459 │ male   │ 52.0    │
# │ 460 │ male   │ 19.0    │
# │ 461 │ male   │ 30.7266 │
# │ 462 │ male   │ 33.0    │
# │ 463 │ male   │ 17.0    │
# │ 464 │ male   │ 34.0    │
# │ 465 │ male   │ 50.0    │
# │ 466 │ male   │ 27.0    │
# │ 467 │ male   │ 20.0    │
# │ 468 │ male   │ 25.0    │
# │ 469 │ male   │ 11.0    │
# │ 470 │ male   │ 30.7266 │
# │ 471 │ male   │ 23.0    │
# │ 472 │ male   │ 23.0    │
# │ 473 │ male   │ 28.5    │
# │ 474 │ male   │ 35.0    │
# │ 475 │ male   │ 30.7266 │
# │ 476 │ male   │ 30.7266 │
# │ 477 │ male   │ 30.7266 │
# │ 478 │ male   │ 36.0    │
# │ 479 │ male   │ 24.0    │
# │ 480 │ male   │ 31.0    │
# │ 481 │ male   │ 70.0    │
# │ 482 │ male   │ 16.0    │
# │ 483 │ male   │ 19.0    │
# │ 484 │ male   │ 31.0    │
# │ 485 │ male   │ 6.0     │
# │ 486 │ male   │ 33.0    │
# │ 487 │ male   │ 23.0    │
# │ 488 │ male   │ 0.67    │
# │ 489 │ male   │ 28.0    │
# │ 490 │ male   │ 18.0    │
# │ 491 │ male   │ 34.0    │
# │ 492 │ male   │ 30.7266 │
# │ 493 │ male   │ 41.0    │
# │ 494 │ male   │ 20.0    │
# │ 495 │ male   │ 16.0    │
# │ 496 │ male   │ 30.7266 │
# │ 497 │ male   │ 30.7266 │
# │ 498 │ male   │ 32.0    │
# │ 499 │ male   │ 24.0    │
# │ 500 │ male   │ 48.0    │
# │ 501 │ male   │ 30.7266 │
# │ 502 │ male   │ 18.0    │
# │ 503 │ male   │ 30.7266 │
# │ 504 │ male   │ 30.7266 │
# │ 505 │ male   │ 29.0    │
# │ 506 │ male   │ 30.7266 │
# │ 507 │ male   │ 25.0    │
# │ 508 │ male   │ 25.0    │
# │ 509 │ male   │ 8.0     │
# │ 510 │ male   │ 1.0     │
# │ 511 │ male   │ 46.0    │
# │ 512 │ male   │ 30.7266 │
# │ 513 │ male   │ 16.0    │
# │ 514 │ male   │ 30.7266 │
# │ 515 │ male   │ 25.0    │
# │ 516 │ male   │ 39.0    │
# │ 517 │ male   │ 30.0    │
# │ 518 │ male   │ 34.0    │
# │ 519 │ male   │ 11.0    │
# │ 520 │ male   │ 0.42    │
# │ 521 │ male   │ 27.0    │
# │ 522 │ male   │ 31.0    │
# │ 523 │ male   │ 39.0    │
# │ 524 │ male   │ 39.0    │
# │ 525 │ male   │ 26.0    │
# │ 526 │ male   │ 39.0    │
# │ 527 │ male   │ 35.0    │
# │ 528 │ male   │ 30.5    │
# │ 529 │ male   │ 30.7266 │
# │ 530 │ male   │ 31.0    │
# │ 531 │ male   │ 43.0    │
# │ 532 │ male   │ 10.0    │
# │ 533 │ male   │ 27.0    │
# │ 534 │ male   │ 38.0    │
# │ 535 │ male   │ 2.0     │
# │ 536 │ male   │ 30.7266 │
# │ 537 │ male   │ 30.7266 │
# │ 538 │ male   │ 1.0     │
# │ 539 │ male   │ 30.7266 │
# │ 540 │ male   │ 0.83    │
# │ 541 │ male   │ 30.7266 │
# │ 542 │ male   │ 23.0    │
# │ 543 │ male   │ 18.0    │
# │ 544 │ male   │ 21.0    │
# │ 545 │ male   │ 30.7266 │
# │ 546 │ male   │ 32.0    │
# │ 547 │ male   │ 30.7266 │
# │ 548 │ male   │ 20.0    │
# │ 549 │ male   │ 16.0    │
# │ 550 │ male   │ 34.5    │
# │ 551 │ male   │ 17.0    │
# │ 552 │ male   │ 42.0    │
# │ 553 │ male   │ 30.7266 │
# │ 554 │ male   │ 35.0    │
# │ 555 │ male   │ 28.0    │
# │ 556 │ male   │ 4.0     │
# │ 557 │ male   │ 74.0    │
# │ 558 │ male   │ 51.0    │
# │ 559 │ male   │ 30.7266 │
# │ 560 │ male   │ 41.0    │
# │ 561 │ male   │ 21.0    │
# │ 562 │ male   │ 24.0    │
# │ 563 │ male   │ 31.0    │
# │ 564 │ male   │ 30.7266 │
# │ 565 │ male   │ 4.0     │
# │ 566 │ male   │ 26.0    │
# │ 567 │ male   │ 33.0    │
# │ 568 │ male   │ 47.0    │
# │ 569 │ male   │ 20.0    │
# │ 570 │ male   │ 19.0    │
# │ 571 │ male   │ 30.7266 │
# │ 572 │ male   │ 33.0    │
# │ 573 │ male   │ 28.0    │
# │ 574 │ male   │ 25.0    │
# │ 575 │ male   │ 27.0    │
# │ 576 │ male   │ 26.0    │
# │ 577 │ male   │ 32.0    │
# │ 578 │ female │ 38.0    │
# │ 579 │ female │ 26.0    │
# │ 580 │ female │ 35.0    │
# │ 581 │ female │ 27.0    │
# │ 582 │ female │ 14.0    │
# │ 583 │ female │ 4.0     │
# │ 584 │ female │ 58.0    │
# │ 585 │ female │ 14.0    │
# │ 586 │ female │ 55.0    │
# │ 587 │ female │ 31.0    │
# │ 588 │ female │ 27.9157 │
# │ 589 │ female │ 15.0    │
# │ 590 │ female │ 8.0     │
# │ 591 │ female │ 38.0    │
# │ 592 │ female │ 27.9157 │
# │ 593 │ female │ 27.9157 │
# │ 594 │ female │ 27.9157 │
# │ 595 │ female │ 18.0    │
# │ 596 │ female │ 14.0    │
# │ 597 │ female │ 40.0    │
# │ 598 │ female │ 27.0    │
# │ 599 │ female │ 3.0     │
# │ 600 │ female │ 19.0    │
# │ 601 │ female │ 27.9157 │
# │ 602 │ female │ 18.0    │
# │ 603 │ female │ 49.0    │
# │ 604 │ female │ 29.0    │
# │ 605 │ female │ 21.0    │
# │ 606 │ female │ 5.0     │
# │ 607 │ female │ 38.0    │
# │ 608 │ female │ 29.0    │
# │ 609 │ female │ 17.0    │
# │ 610 │ female │ 16.0    │
# │ 611 │ female │ 30.0    │
# │ 612 │ female │ 27.9157 │
# │ 613 │ female │ 17.0    │
# │ 614 │ female │ 33.0    │
# │ 615 │ female │ 23.0    │
# │ 616 │ female │ 34.0    │
# │ 617 │ female │ 28.0    │
# │ 618 │ female │ 21.0    │
# │ 619 │ female │ 27.9157 │
# │ 620 │ female │ 14.5    │
# │ 621 │ female │ 20.0    │
# │ 622 │ female │ 17.0    │
# │ 623 │ female │ 2.0     │
# │ 624 │ female │ 32.5    │
# │ 625 │ female │ 27.9157 │
# │ 626 │ female │ 47.0    │
# │ 627 │ female │ 29.0    │
# │ 628 │ female │ 19.0    │
# │ 629 │ female │ 27.9157 │
# │ 630 │ female │ 22.0    │
# │ 631 │ female │ 24.0    │
# │ 632 │ female │ 9.0     │
# │ 633 │ female │ 22.0    │
# │ 634 │ female │ 16.0    │
# │ 635 │ female │ 40.0    │
# │ 636 │ female │ 27.9157 │
# │ 637 │ female │ 45.0    │
# │ 638 │ female │ 1.0     │
# │ 639 │ female │ 50.0    │
# │ 640 │ female │ 27.9157 │
# │ 641 │ female │ 4.0     │
# │ 642 │ female │ 27.9157 │
# │ 643 │ female │ 32.0    │
# │ 644 │ female │ 19.0    │
# │ 645 │ female │ 44.0    │
# │ 646 │ female │ 58.0    │
# │ 647 │ female │ 27.9157 │
# │ 648 │ female │ 24.0    │
# │ 649 │ female │ 2.0     │
# │ 650 │ female │ 16.0    │
# │ 651 │ female │ 35.0    │
# │ 652 │ female │ 31.0    │
# │ 653 │ female │ 27.0    │
# │ 654 │ female │ 32.0    │
# │ 655 │ female │ 27.9157 │
# │ 656 │ female │ 35.0    │
# │ 657 │ female │ 5.0     │
# │ 658 │ female │ 27.9157 │
# │ 659 │ female │ 8.0     │
# │ 660 │ female │ 27.9157 │
# │ 661 │ female │ 27.9157 │
# │ 662 │ female │ 25.0    │
# │ 663 │ female │ 24.0    │
# │ 664 │ female │ 29.0    │
# │ 665 │ female │ 41.0    │
# │ 666 │ female │ 29.0    │
# │ 667 │ female │ 27.9157 │
# │ 668 │ female │ 30.0    │
# │ 669 │ female │ 35.0    │
# │ 670 │ female │ 50.0    │
# │ 671 │ female │ 27.9157 │
# │ 672 │ female │ 58.0    │
# │ 673 │ female │ 35.0    │
# │ 674 │ female │ 41.0    │
# │ 675 │ female │ 27.9157 │
# │ 676 │ female │ 63.0    │
# │ 677 │ female │ 45.0    │
# │ 678 │ female │ 35.0    │
# │ 679 │ female │ 22.0    │
# │ 680 │ female │ 26.0    │
# │ 681 │ female │ 19.0    │
# │ 682 │ female │ 24.0    │
# │ 683 │ female │ 2.0     │
# │ 684 │ female │ 50.0    │
# │ 685 │ female │ 27.9157 │
# │ 686 │ female │ 27.9157 │
# │ 687 │ female │ 27.9157 │
# │ 688 │ female │ 17.0    │
# │ 689 │ female │ 30.0    │
# │ 690 │ female │ 24.0    │
# │ 691 │ female │ 18.0    │
# │ 692 │ female │ 26.0    │
# │ 693 │ female │ 26.0    │
# │ 694 │ female │ 24.0    │
# │ 695 │ female │ 31.0    │
# │ 696 │ female │ 40.0    │
# │ 697 │ female │ 30.0    │
# │ 698 │ female │ 22.0    │
# │ 699 │ female │ 36.0    │
# │ 700 │ female │ 36.0    │
# │ 701 │ female │ 31.0    │
# │ 702 │ female │ 16.0    │
# │ 703 │ female │ 27.9157 │
# │ 704 │ female │ 27.9157 │
# │ 705 │ female │ 41.0    │
# │ 706 │ female │ 24.0    │
# │ 707 │ female │ 24.0    │
# │ 708 │ female │ 40.0    │
# │ 709 │ female │ 27.9157 │
# │ 710 │ female │ 22.0    │
# │ 711 │ female │ 38.0    │
# │ 712 │ female │ 27.9157 │
# │ 713 │ female │ 27.9157 │
# │ 714 │ female │ 45.0    │
# │ 715 │ female │ 60.0    │
# │ 716 │ female │ 27.9157 │
# │ 717 │ female │ 27.9157 │
# │ 718 │ female │ 24.0    │
# │ 719 │ female │ 3.0     │
# │ 720 │ female │ 27.9157 │
# │ 721 │ female │ 22.0    │
# │ 722 │ female │ 42.0    │
# │ 723 │ female │ 1.0     │
# │ 724 │ female │ 35.0    │
# │ 725 │ female │ 36.0    │
# │ 726 │ female │ 17.0    │
# │ 727 │ female │ 23.0    │
# │ 728 │ female │ 24.0    │
# │ 729 │ female │ 31.0    │
# │ 730 │ female │ 28.0    │
# │ 731 │ female │ 21.0    │
# │ 732 │ female │ 20.0    │
# │ 733 │ female │ 27.9157 │
# │ 734 │ female │ 33.0    │
# │ 735 │ female │ 27.9157 │
# │ 736 │ female │ 34.0    │
# │ 737 │ female │ 18.0    │
# │ 738 │ female │ 10.0    │
# │ 739 │ female │ 28.0    │
# │ 740 │ female │ 28.0    │
# │ 741 │ female │ 19.0    │
# │ 742 │ female │ 27.9157 │
# │ 743 │ female │ 42.0    │
# │ 744 │ female │ 14.0    │
# │ 745 │ female │ 21.0    │
# │ 746 │ female │ 24.0    │
# │ 747 │ female │ 45.0    │
# │ 748 │ female │ 28.0    │
# │ 749 │ female │ 13.0    │
# │ 750 │ female │ 5.0     │
# │ 751 │ female │ 27.9157 │
# │ 752 │ female │ 50.0    │
# │ 753 │ female │ 0.75    │
# │ 754 │ female │ 33.0    │
# │ 755 │ female │ 23.0    │
# │ 756 │ female │ 22.0    │
# │ 757 │ female │ 2.0     │
# │ 758 │ female │ 63.0    │
# │ 759 │ female │ 27.9157 │
# │ 760 │ female │ 35.0    │
# │ 761 │ female │ 54.0    │
# │ 762 │ female │ 25.0    │
# │ 763 │ female │ 21.0    │
# │ 764 │ female │ 27.9157 │
# │ 765 │ female │ 37.0    │
# │ 766 │ female │ 16.0    │
# │ 767 │ female │ 33.0    │
# │ 768 │ female │ 54.0    │
# │ 769 │ female │ 34.0    │
# │ 770 │ female │ 36.0    │
# │ 771 │ female │ 30.0    │
# │ 772 │ female │ 44.0    │
# │ 773 │ female │ 50.0    │
# │ 774 │ female │ 2.0     │
# │ 775 │ female │ 27.9157 │
# │ 776 │ female │ 30.0    │
# │ 777 │ female │ 7.0     │
# │ 778 │ female │ 30.0    │
# │ 779 │ female │ 22.0    │
# │ 780 │ female │ 36.0    │
# │ 781 │ female │ 9.0     │
# │ 782 │ female │ 11.0    │
# │ 783 │ female │ 19.0    │
# │ 784 │ female │ 22.0    │
# │ 785 │ female │ 48.0    │
# │ 786 │ female │ 39.0    │
# │ 787 │ female │ 36.0    │
# │ 788 │ female │ 27.9157 │
# │ 789 │ female │ 29.0    │
# │ 790 │ female │ 53.0    │
# │ 791 │ female │ 27.9157 │
# │ 792 │ female │ 34.0    │
# │ 793 │ female │ 39.0    │
# │ 794 │ female │ 27.9157 │
# │ 795 │ female │ 25.0    │
# │ 796 │ female │ 39.0    │
# │ 797 │ female │ 18.0    │
# │ 798 │ female │ 52.0    │
# │ 799 │ female │ 27.9157 │
# │ 800 │ female │ 27.9157 │
# │ 801 │ female │ 24.0    │
# │ 802 │ female │ 22.0    │
# │ 803 │ female │ 40.0    │
# │ 804 │ female │ 39.0    │
# │ 805 │ female │ 27.9157 │
# │ 806 │ female │ 24.0    │
# │ 807 │ female │ 26.0    │
# │ 808 │ female │ 4.0     │
# │ 809 │ female │ 21.0    │
# │ 810 │ female │ 9.0     │
# │ 811 │ female │ 28.0    │
# │ 812 │ female │ 41.0    │
# │ 813 │ female │ 24.0    │
# │ 814 │ female │ 2.0     │
# │ 815 │ female │ 0.75    │
# │ 816 │ female │ 23.0    │
# │ 817 │ female │ 18.0    │
# │ 818 │ female │ 27.9157 │
# │ 819 │ female │ 18.0    │
# │ 820 │ female │ 32.0    │
# │ 821 │ female │ 27.9157 │
# │ 822 │ female │ 40.0    │
# │ 823 │ female │ 18.0    │
# │ 824 │ female │ 43.0    │
# │ 825 │ female │ 27.9157 │
# │ 826 │ female │ 15.0    │
# │ 827 │ female │ 4.0     │
# │ 828 │ female │ 27.9157 │
# │ 829 │ female │ 18.0    │
# │ 830 │ female │ 18.0    │
# │ 831 │ female │ 45.0    │
# │ 832 │ female │ 22.0    │
# │ 833 │ female │ 24.0    │
# │ 834 │ female │ 38.0    │
# │ 835 │ female │ 27.0    │
# │ 836 │ female │ 6.0     │
# │ 837 │ female │ 30.0    │
# │ 838 │ female │ 27.9157 │
# │ 839 │ female │ 25.0    │
# │ 840 │ female │ 29.0    │
# │ 841 │ female │ 48.0    │
# │ 842 │ female │ 21.0    │
# │ 843 │ female │ 30.0    │
# │ 844 │ female │ 4.0     │
# │ 845 │ female │ 48.0    │
# │ 846 │ female │ 33.0    │
# │ 847 │ female │ 36.0    │
# │ 848 │ female │ 51.0    │
# │ 849 │ female │ 30.5    │
# │ 850 │ female │ 57.0    │
# │ 851 │ female │ 54.0    │
# │ 852 │ female │ 5.0     │
# │ 853 │ female │ 43.0    │
# │ 854 │ female │ 13.0    │
# │ 855 │ female │ 17.0    │
# │ 856 │ female │ 18.0    │
# │ 857 │ female │ 27.9157 │
# │ 858 │ female │ 49.0    │
# │ 859 │ female │ 31.0    │
# │ 860 │ female │ 30.0    │
# │ 861 │ female │ 31.0    │
# │ 862 │ female │ 18.0    │
# │ 863 │ female │ 33.0    │
# │ 864 │ female │ 6.0     │
# │ 865 │ female │ 23.0    │
# │ 866 │ female │ 52.0    │
# │ 867 │ female │ 27.0    │
# │ 868 │ female │ 62.0    │
# │ 869 │ female │ 15.0    │
# │ 870 │ female │ 39.0    │
# │ 871 │ female │ 30.0    │
# │ 872 │ female │ 27.9157 │
# │ 873 │ female │ 9.0     │
# │ 874 │ female │ 16.0    │
# │ 875 │ female │ 44.0    │
# │ 876 │ female │ 18.0    │
# │ 877 │ female │ 45.0    │
# │ 878 │ female │ 24.0    │
# │ 879 │ female │ 48.0    │
# │ 880 │ female │ 27.9157 │
# │ 881 │ female │ 42.0    │
# │ 882 │ female │ 27.0    │
# │ 883 │ female │ 47.0    │
# │ 884 │ female │ 28.0    │
# │ 885 │ female │ 15.0    │
# │ 886 │ female │ 56.0    │
# │ 887 │ female │ 25.0    │
# │ 888 │ female │ 22.0    │
# │ 889 │ female │ 39.0    │
# │ 890 │ female │ 19.0    │
# │ 891 │ female │ 27.9157 │
